# %% [markdown]
# ejercicio 1

# %%
a = float(input(" valor a: "))
b = float(input(" valor b: "))
c = float(input(" valor c: "))

discriminante= (b**2)-4*a*c

while (discriminante<0):
  print("Error el discriminante tiene que ser positivo")
  a = float(input("valor a: "))
  b = float(input("valor b: "))
  c = float(input("valor c: "))
  discriminante= (b**2)-4*a*c
     
if discriminante==0:
    x= -b/(2*a)
    print("X solo tiene una solucion = ",x)
else: 
    x1= (-b-(discriminante**0.5))/(2*a)
    x2= (-b+(discriminante**0.5))/(2*a)
    print(" X1 =",x1)
    print(" X2 =",x2)
# Out:
#  valor a: 4
#  valor b: -30
#  valor c: 56
#  X1 = 3.5
#  X2 = 4.0

# %% [markdown]
# ejercicio2

# %%
def funcion(x):
   x=(x*x)+(3.0*x)+3.0
   return [x]

miLista=[]

i=-4.0
f=10.0
while i<=f:
  z=i
  x=-4
  while z==3 and x<=3:
    y=funcion(x)
    print(y)
    t=y
    x=x+1
    miLista.append(t)
    
  i=i+1
print(miLista)
# Out:
# [7.0]
# [3.0]
# [1.0]
# [1.0]
# [3.0]
# [7.0]
# [13.0]
# [21.0]
# [[7.0], [3.0], [1.0], [1.0], [3.0], [7.0], [13.0], [21.0]]
